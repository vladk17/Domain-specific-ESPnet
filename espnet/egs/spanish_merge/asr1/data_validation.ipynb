# %%
DATASET_PATH = 'gong'
GENERATIVE_PATH = f'data/train_{DATASET_PATH}'

# %%
import os
import pandas as pd
import random
import IPython.display as ipd

# %%
path_to_wav = os.path.join(GENERATIVE_PATH, 'wav.scp')
path_to_text = os.path.join(GENERATIVE_PATH, 'text')

# %%
with open(path_to_text) as f:
    d = f.readlines()
texts = {item.split(' ')[0]: ' '.join(item.split(' ')[1:]).replace('\n','')  for item in d}

# %%
with open(path_to_wav) as f:
    d = f.readlines()
wavs = {item.split(' ')[0]: ' '.join(item.split(' ')[1:]).replace('\n','')  for item in d}

# %%
random_utterances = []
for i in range(10):
    utt_id = random.choice(list(texts.keys()))
    text = texts[utt_id]
    wav_path = wavs[utt_id]
    random_utterances.append({"id":utt_id,'text':text,'path':wav_path})

# %%
random_utterances
# Out:
# [{'id': 'gongsp4525996740327528400-gong1809',
#   'text': 'nosotros capaz tenemos la',
#   'path': 'downloads/gong/5417432236577935718.raw-audio133.wav'},
#  {'id': 'gongsp5991998457267644000-gong1713',
#   'text': 'unk',
#   'path': 'downloads/gong/5417432236577935718.raw-audio14.wav'},
#  {'id': 'gongsp[Speaker3]-gong2381',
#   'text': 'entonces el diecinueve el miércoles el diecinueve a las diez y media le sirve de nuevo',
#   'path': 'downloads/gong/7002112321545364910.raw-audio284.wav'},
#  {'id': 'gongsp1014916540643794300-gong947',
#   'text': 'con tarjeta de crédito o',
#   'path': 'downloads/gong/3418108921371474961.raw-audio126.wav'},
#  {'id': 'gongspPeter-gong1289',
#   'text': 'okey',
#   'path': 'downloads/gong/4376713762901091184.raw-audio106.wav'},
#  {'id': 'gongsp1642791620339587800-gong1523',
#   'text': 'pues cambiar las cosas',
#   'path': 'downloads/gong/504819441125717082.raw-audio74.wav'},
#  {'id': 'gongsp5203906623316679000-gong900',
#   'text': 'este una pregunta',
#   'path': 'downloads/gong/3418108921371474961.raw-audio54.wav'},
#  {'id': 'gongsp8753889133246605000-gong2064',
#   'text': 'ah correcto sí acabo de recibir tu información hace unos minutos',
#   'path': 'downloads/gong/5603819377472017823.raw-audio25.wav'},
#  {'id': 'gongsp792030565976926700-gong2438',
#   'text': 'eh manejaba lo de offline pero ya cuando fui a hacer',
#   'path': 'downloads/gong/7854739097239330284.raw-audio48.wav'},
#  {'id': 'gongsp2160694275457040100-gong90',
#   'text': 'porque hay hay en casos donde más le ponen como un',
#   'path': 'downloads/gong/1005862420391356161.raw-audio117.wav'}]

# %%
utt = random.choice(random_utterances)
print('id:', utt['id'])
print('text:', utt['text'])
ipd.Audio(utt['path'])
# Out:
# id: gongsp5203906623316679000-gong900
# text: este una pregunta
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
