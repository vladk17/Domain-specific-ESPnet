# %%
DATASET_PATH = 'gong'
GENERATIVE_PATH = f'data/train_{DATASET_PATH}'

# %%
import os
import pandas as pd
import random
import IPython.display as ipd

# %%
path_to_wav = os.path.join(GENERATIVE_PATH, 'wav.scp')
path_to_text = os.path.join(GENERATIVE_PATH, 'text')

# %%
with open(path_to_text) as f:
    d = f.readlines()
texts = {item.split(' ')[0]: ' '.join(item.split(' ')[1:]).replace('\n','')  for item in d}

# %%
with open(path_to_wav) as f:
    d = f.readlines()
wavs = {item.split(' ')[0]: ' '.join(item.split(' ')[1:]).replace('\n','')  for item in d}

# %%
random_utterances = []
for i in range(10):
    utt_id = random.choice(list(texts.keys()))
    text = texts[utt_id]
    wav_path = wavs[utt_id]
    random_utterances.append({"id":utt_id,'text':text,'path':wav_path})

# %%
utt = random.choice(random_utterances)
print('id:', utt['id'])
print('text:', utt['text'])
ipd.Audio(utt['path'])
# Out:
# id: gongsp2974559822989846000-gong1371
# text: okey algo me comentó
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
utt_id = 'gongsp2155764364423764000-gong832'

print(texts[utt_id])
ipd.Audio(wavs[utt_id])
# Out:
# pero a mí ya no me sirve a mi trescientos quinientos esos me los hago yo
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
